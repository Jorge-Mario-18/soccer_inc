# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-Mario-18/soccer_inc/blob/main/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import packages
import pandas as pd

# %%
#Read CSV
logins = pd.read_csv('LoginHistory.csv')

# %%
#Drop Columns
logins.drop(columns = ['Logged out', 'Location', 'Client Type'])
# Out:
#                            User         Logged in
# 0      generic_user@fakeinc.com  2022-12-02 14:34
# 1      generic_user@fakeinc.com  2022-12-02 14:31
# 2      generic_user@fakeinc.com  2022-12-02 14:30
# 3      generic_user@fakeinc.com  2022-12-02 14:26
# 4      generic_user@fakeinc.com  2022-12-02 13:43
# ...                         ...               ...
# 31242  generic_user@fakeinc.com  2020-01-02 02:04
# 31243  generic_user@fakeinc.com  2020-01-01 21:33
# 31244  generic_user@fakeinc.com  2020-01-01 15:43
# 31245  generic_user@fakeinc.com  2020-01-01 09:41
# 31246  generic_user@fakeinc.com  2020-01-01 05:55
#
# [31247 rows x 2 columns]

# %%
# Retrives login data from 'Logged in' column 
loginTime = logins['Logged in']

# %%
#Seperates the the 'Date' and 'Time' of login
time = []
date = []

for i in loginTime:
  txt = i.split(' ', 1)
  time.append(txt[1])
  date.append(txt[0])

# %%
# Creates the number of login occurances by date
rep = {}
for i in date:
  rep[i] = date.count(i)

# %%
# Creates data frame with Columns 
df = pd.DataFrame(columns=['Day', 'Count'])

# %%
# Seperates the values from the list into x and y values 
lists = sorted(rep.items())
x, y = zip(*lists)

# %%
# Adds the data for 'Day' and 'Count' columns
df['Day'] = x
df['Count'] = y

# %%
# Creates visual graph of the data
import matplotlib.pyplot as plt

plt.plot(x, y)
plt.ylabel('Login Count')
plt.xlabel('Day of Login Occurance')
plt.savefig('DailyLogins.png')
plt.show()

# %%
# Drops outliers of more then 80 logins per day
df.drop(df[df['Count'] > 80].index, inplace = True)
df = df.reset_index(drop=True)

# %%
# New plot with outliers removed past 80 logins 
import matplotlib.pyplot as plt

plt.plot(df['Day'], df['Count'])
plt.ylabel('Login Count')
plt.xlabel('Day of Login Occurance')
plt.savefig('DailyLogins.png')
plt.show()

# %%
#For Indexing based on Quarters
print(df[df['Day'] == '2020-01-01'].index.values, " <--- This is the start of Q1 2020")
print()
print(df[df['Day'] == '2020-04-01'].index.values, " <--- This is the start of Q2 2020")
print()
print(df[df['Day'] == '2020-07-03'].index.values, " <--- This is the start of Q3 2020")
print()
print(df[df['Day'] == '2020-10-01'].index.values, " <--- This is the start of Q4 2020")
print()
print(df[df['Day'] == '2021-01-01'].index.values, " <--- This is the start of Q1 2021")
print()
print(df[df['Day'] == '2021-04-01'].index.values, " <--- This is the start of Q2 2021")
print()
print(df[df['Day'] == '2021-07-01'].index.values, " <--- This is the start of Q3 2021")
print()
print(df[df['Day'] == '2021-10-01'].index.values, " <--- This is the start of Q4 2021")
print()
print(df[df['Day'] == '2022-01-02'].index.values, " <--- This is the start of Q1 2022")
print()
print(df[df['Day'] == '2022-04-01'].index.values, " <--- This is the start of Q2 2022")
print()
print(df[df['Day'] == '2022-07-01'].index.values, " <--- This is the start of Q3 2022")
print()
print(df[df['Day'] == '2022-10-01'].index.values, " <--- This is the start of Q4 2022")
# Out:
# [0]  <--- This is the start of Q1 2020
#
# [84]  <--- This is the start of Q2 2020
#
# [165]  <--- This is the start of Q3 2020
#
# [247]  <--- This is the start of Q4 2020
#
# [333]  <--- This is the start of Q1 2021
#
# [420]  <--- This is the start of Q2 2021
#
# [510]  <--- This is the start of Q3 2021
#
# [600]  <--- This is the start of Q4 2021
#
# [687]  <--- This is the start of Q1 2022
#
# [772]  <--- This is the start of Q2 2022
#
# [858]  <--- This is the start of Q3 2022
#
# [949]  <--- This is the start of Q4 2022

# %%
Q1_2020 = df.iloc[0:84]
Q1_2020=Q1_2020.reset_index(drop=True)
Q1_2020.to_csv('Q1_2020.csv')
Q1_2020

# %%
Q2_2020 = df.iloc[84:165]
Q2_2020=Q2_2020.reset_index(drop=True)
Q2_2020.to_csv('Q2_2020.csv')
Q2_2020
# Out:
#            Day  Count
# 0   2020-04-01     42
# 1   2020-04-02     36
# 2   2020-04-03     45
# 3   2020-04-04      6
# 4   2020-04-05     10
# ..         ...    ...
# 76  2020-06-26     48
# 77  2020-06-27     11
# 78  2020-06-28      8
# 79  2020-06-29     58
# 80  2020-06-30     66
#
# [81 rows x 2 columns]

# %%
Q3_2020 = df.iloc[165:247]
Q3_2020=Q3_2020.reset_index(drop=True)
Q3_2020.to_csv('Q3_2020.csv')
Q3_2020
# Out:
#            Day  Count
# 0   2020-07-03      7
# 1   2020-07-04     24
# 2   2020-07-05      3
# 3   2020-07-06     61
# 4   2020-07-07     43
# ..         ...    ...
# 77  2020-09-26      1
# 78  2020-09-27      5
# 79  2020-09-28     41
# 80  2020-09-29     30
# 81  2020-09-30     56
#
# [82 rows x 2 columns]

# %%
Q4_2020 = df.iloc[247:333]
Q4_2020=Q4_2020.reset_index(drop=True)
Q4_2020.to_csv('Q4_2020.csv')
Q4_2020
# Out:
#            Day  Count
# 0   2020-10-01     57
# 1   2020-10-02     32
# 2   2020-10-03      1
# 3   2020-10-04      2
# 4   2020-10-06     43
# ..         ...    ...
# 81  2020-12-27      2
# 82  2020-12-28     24
# 83  2020-12-29     20
# 84  2020-12-30     22
# 85  2020-12-31      7
#
# [86 rows x 2 columns]

# %%
Q1_2021 = df.iloc[333:420]
Q1_2021=Q1_2021.reset_index(drop=True)
Q1_2021.to_csv('Q1_2021.csv')
Q1_2021
# Out:
#            Day  Count
# 0   2021-01-01      1
# 1   2021-01-02      2
# 2   2021-01-03      2
# 3   2021-01-04     43
# 4   2021-01-06     46
# ..         ...    ...
# 82  2021-03-27      6
# 83  2021-03-28      9
# 84  2021-03-29     25
# 85  2021-03-30     37
# 86  2021-03-31     31
#
# [87 rows x 2 columns]

# %%
Q2_2021 = df.iloc[420:510]
Q2_2021=Q2_2021.reset_index(drop=True)
Q2_2021.to_csv('Q2_2021.csv')
Q2_2021
# Out:
#            Day  Count
# 0   2021-04-01     34
# 1   2021-04-02     24
# 2   2021-04-03     13
# 3   2021-04-04      6
# 4   2021-04-05     35
# ..         ...    ...
# 85  2021-06-26      1
# 86  2021-06-27      3
# 87  2021-06-28     31
# 88  2021-06-29     29
# 89  2021-06-30     30
#
# [90 rows x 2 columns]

# %%
Q3_2021 = df.iloc[510:600]
Q3_2021=Q3_2021.reset_index(drop=True)
Q3_2021.to_csv('Q3_2021.csv')
Q3_2021
# Out:
#            Day  Count
# 0   2021-07-01     52
# 1   2021-07-02     33
# 2   2021-07-03      3
# 3   2021-07-05      1
# 4   2021-07-06     24
# ..         ...    ...
# 85  2021-09-26      3
# 86  2021-09-27     39
# 87  2021-09-28     38
# 88  2021-09-29     42
# 89  2021-09-30     39
#
# [90 rows x 2 columns]

# %%
Q4_2021 = df.iloc[600:687]
Q4_2021=Q4_2021.reset_index(drop=True)
Q4_2021.to_csv('Q4_2021.csv')
Q4_2021
# Out:
#            Day  Count
# 0   2021-10-01     30
# 1   2021-10-02      7
# 2   2021-10-03     12
# 3   2021-10-04     38
# 4   2021-10-05     42
# ..         ...    ...
# 82  2021-12-27     13
# 83  2021-12-28     14
# 84  2021-12-29     12
# 85  2021-12-30     13
# 86  2021-12-31      3
#
# [87 rows x 2 columns]

# %%
Q1_2022 = df.iloc[687:772]
Q1_2022=Q1_2022.reset_index(drop=True)
Q1_2022.to_csv('Q1_2022.csv')
Q1_2022
# Out:
#            Day  Count
# 0   2022-01-02      3
# 1   2022-01-03     32
# 2   2022-01-04     41
# 3   2022-01-05     37
# 4   2022-01-06     25
# ..         ...    ...
# 80  2022-03-27      3
# 81  2022-03-28     33
# 82  2022-03-29     35
# 83  2022-03-30     25
# 84  2022-03-31     32
#
# [85 rows x 2 columns]

# %%
Q2_2022 = df.iloc[772:858]
Q2_2022=Q2_2022.reset_index(drop=True)
Q2_2022.to_csv('Q2_2022.csv')
Q2_2022
# Out:
#            Day  Count
# 0   2022-04-01     10
# 1   2022-04-02      5
# 2   2022-04-03      1
# 3   2022-04-04     20
# 4   2022-04-05     15
# ..         ...    ...
# 81  2022-06-26      1
# 82  2022-06-27     43
# 83  2022-06-28     59
# 84  2022-06-29     42
# 85  2022-06-30     41
#
# [86 rows x 2 columns]

# %%
Q3_2022 = df.iloc[858:949]
Q3_2022=Q3_2022.reset_index(drop=True)
Q3_2022.to_csv('Q3_2022.csv')
Q3_2022
# Out:
#            Day  Count
# 0   2022-07-01      4
# 1   2022-07-02      3
# 2   2022-07-03      3
# 3   2022-07-04      1
# 4   2022-07-05     37
# ..         ...    ...
# 86  2022-09-26     57
# 87  2022-09-27     53
# 88  2022-09-28     57
# 89  2022-09-29     43
# 90  2022-09-30     36
#
# [91 rows x 2 columns]

# %%
Q4_2022 = df.iloc[949:]
Q4_2022=Q4_2022.reset_index(drop=True)
Q4_2022.to_csv('Q4_2022.csv')
Q4_2022
# Out:
#            Day  Count
# 0   2022-10-01      1
# 1   2022-10-02      3
# 2   2022-10-03     48
# 3   2022-10-04     43
# 4   2022-10-05     55
# 5   2022-10-06     40
# 6   2022-10-07     21
# 7   2022-10-09      6
# 8   2022-10-10     48
# 9   2022-10-11     39
# 10  2022-10-12     43
# 11  2022-10-13     31
# 12  2022-10-14     26
# 13  2022-10-15      4
# 14  2022-10-16      4
# 15  2022-10-17     59
# 16  2022-10-18     42
# 17  2022-10-19     42
# 18  2022-10-20     51
# 19  2022-10-21     32
# 20  2022-10-22      2
# 21  2022-10-23      9
# 22  2022-10-24     45
# 23  2022-10-25     52
# 24  2022-10-26     49
# 25  2022-10-27     55
# 26  2022-10-28     29
# 27  2022-10-30      2
# 28  2022-10-31     52
# 29  2022-11-01     47
# 30  2022-11-02     45
# 31  2022-11-03     50
# 32  2022-11-04     28
# 33  2022-11-05      5
# 34  2022-11-06      4
# 35  2022-11-07     45
# 36  2022-11-08     64
# 37  2022-11-09     41
# 38  2022-11-10     56
# 39  2022-11-11     33
# ...

# %%
#2020
Q1_20_mean = sum(Q1_2020["Count"])/len(Q1_2020["Count"])
Q2_20_mean = sum(Q2_2020["Count"])/len(Q2_2020["Count"])
Q3_20_mean = sum(Q3_2020["Count"])/len(Q3_2020["Count"])
Q4_20_mean = sum(Q4_2020["Count"])/len(Q4_2020["Count"])

#2021
Q1_21_mean = sum(Q1_2021["Count"])/len(Q1_2021["Count"])
Q2_21_mean = sum(Q2_2021["Count"])/len(Q2_2021["Count"])
Q3_21_mean = sum(Q3_2021["Count"])/len(Q3_2021["Count"])
Q4_21_mean = sum(Q4_2021["Count"])/len(Q4_2021["Count"])

#2022
Q1_22_mean = sum(Q1_2022["Count"])/len(Q1_2022["Count"])
Q2_22_mean = sum(Q2_2022["Count"])/len(Q2_2022["Count"])
Q3_22_mean = sum(Q3_2022["Count"])/len(Q3_2022["Count"])
Q4_22_mean = sum(Q4_2022["Count"])/len(Q4_2022["Count"])

# %%
#2020
data20 = [[Q1_20_mean, 'Q1-20'], [Q2_20_mean, 'Q2-20'], [Q3_20_mean, 'Q3-20'], [Q4_20_mean, 'Q4-20']]
chart20 = pd.DataFrame(data20, columns=['Average', 'Quater'])
#2021
data21 = [[Q1_21_mean, 'Q1-21'], [Q2_21_mean, 'Q2-21'], [Q3_21_mean, 'Q3-21'], [Q4_21_mean, 'Q4-21']]
chart21 = pd.DataFrame(data21, columns=['Average', 'Quater'])

#2022
data22 = [[Q1_22_mean, 'Q1-22'], [Q2_22_mean, 'Q2-22'], [Q3_22_mean, 'Q3-22'], [Q4_22_mean, 'Q4-22']]
chart22 = pd.DataFrame(data22, columns=['Average', 'Quater'])

#ALL
data_mean = [[Q1_20_mean, 'Q1-20'], [Q2_20_mean, 'Q2-20'], [Q3_20_mean, 'Q3-20'], [Q4_20_mean, 'Q4-20'], 
             [Q1_21_mean, 'Q1-21'], [Q2_21_mean, 'Q2-21'], [Q3_21_mean, 'Q3-21'], [Q4_21_mean, 'Q4-21'], 
             [Q1_22_mean, 'Q1-22'], [Q2_22_mean, 'Q2-22'], [Q3_22_mean, 'Q3-22'], [Q4_22_mean, 'Q4-22']]
chart_all = pd.DataFrame(data_mean, columns=['Average', 'Quater'])

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = chart20.plot(x='Quater', y='Average', ylim=(0, 50), label='2020')

ax = chart21.plot(ax=ax, x='Quater', y='Average', ylim=(0, 50), label='2021')

chart22.plot(ax=ax, x='Quater', y='Average', ylim=(0, 50), label='2022', xlabel='Average for each Quarter')
plt.grid()
plt.ylabel('Login Count')
plt.xticks(np.arange(0, 1, step=0.1))
plt.xticks(np.arange(4))
plt.xticks([0, 1, 2, 3], ['Q1', 'Q2', 'Q3', 'Q4'],
        rotation=20)
plt.xticks()
plt.savefig('Quater-Average.png')

# %%
ax = chart_all.plot(x='Quater', y='Average', ylim=(0, 50), xlabel='Average from 2020 - 2022')
ax.xaxis.set_label_position('top')
plt.axis([0, 11.1, 0, 50])
plt.ylabel('Login Count')
plt.grid()
plt.savefig('Avg20-22.png')
plt.show()
